# %% [markdown]
# ### Antonio Gagliardo | Recipe Sentiment Analysis and Recommendation System
#
# # Index
#
#
# ## [Section 1: Exploring and Cleaning](#Section1)
# ## [Section 2: Tokenize](#Section2)
# ## [Section 3: Vectorize / Tokenize](#Section3)
# ## [Section 4: Recommender](#Section4)
# ## [Section 5: Conclusion](#Section5)
#
#
# ------------------
# -----------------

# %% [markdown]
# ## Intro
#
# In the following jupyter notebook, I will work on a content-based recommendation system for recipes. This means that I will explore on a way taht by giving the input of a recipe name, there will be an output of similar recipes (based on content like ingridients).
#
#
# #### Why is it important?
#
# Content-based recommendations are based on characteristic of the items, and can have some advantages over 'user based' recommendation. One of them is that every user is different and have different taste, so some new users not may like what everyone else likes, or may have some prefference, and when there are new users like that, if it is only recommended  what is popular, it may or may not work; but by ALSO having a recommendation system based on content, we can have a higher chance to recommend something that a new user with peculiar taste actually wants.
#
# Also content-based recommendations can introduce users to new and diverse recipes. By analyzing the attributes of recipes, the system can suggest recipes that are similar in terms of ingredients or cooking methods but may not have been discovered by the user (or users in general). This could also solve the problem taht many of the recipes are never explored. Later on in the exploration it will be explored that there are around 250,000 recipes that were never reviewed, so having a content-based recommendation additionally to the user based can help this unexplored recipes to be viewed.
#
# #### Dataset:
#
# The data was taken from Kaggle and is a dataset from Food.com credit to the person who created the dataset: https://www.kaggle.com/datasets/irkaal/foodcom-recipes-and-reviews
#
# or you can use my **drive link** to download the dataset: https://drive.google.com/drive/folders/17rwRC48Lk1K36z6mU6M3t6ePOsDz51fR

# %% [markdown]
# # Section1
# ### Exploring and Cleaning Data

# %% [markdown]
# First import the required libraries to explor

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Loading the dataset:

# %%
recipes = pd.read_csv('foodcom_with_reviews/recipes.csv', index_col = 'RecipeId')

# %% [markdown]
# Checking the first few columns:

# %%
recipes.head(5)
# Out:
#                                        Name  AuthorId      AuthorName  \
# RecipeId
# 38        Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 39                                  Biryani      1567        elly9812
# 40                            Best Lemonade      1566  Stephen Little
# 41           Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 42                             Cabbage Soup      1538       Duckie067
#
#          CookTime PrepTime TotalTime         DatePublished  \
# RecipeId
# 38          PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 39          PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 40           PT5M    PT30M     PT35M  1999-09-05T19:52:00Z
# 41          PT20M    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 42          PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
#
#                                                 Description  \
# RecipeId
# 38        Make and share this Low-Fat Berry Blue Frozen ...
# 39        Make and share this Biryani recipe from Food.com.
# 40        This is from one of my  first Good House Keepi...
# 41        This dish is best prepared a day in advance to...
# 42        Make and share this Cabbage Soup recipe from F...
#
#                                                      Images   RecipeCategory  \
# RecipeId
# 38        c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# 39        c("https://img.sndimg.com/food/image/upload/w_...   Chicken Breast
# 40        c("https://img.sndimg.com/food/image/upload/w_...        Beverages
# 41        c("https://img.sndimg.com/food/image/upload/w_...         Soy/Tofu
# 42        "https://img.sndimg.com/food/image/upload/w_55...        Vegetable
#
#           ... SaturatedFatContent CholesterolContent SodiumContent  \
# RecipeId  ...
# 38        ...                 1.3                8.0          29.8
# 39        ...                16.6              372.8         368.4
# 40        ...                 0.0                0.0           1.8
# 41        ...                 3.8                0.0        1558.6
# 42        ...                 0.1                0.0         959.3
#
#           CarbohydrateContent  FiberContent  SugarContent  ProteinContent  \
# RecipeId
# 38                       37.1           3.6          30.2             3.2
# 39                       84.4           9.0          20.4            63.4
# 40                       81.5           0.4          77.2             0.3
# 41                       64.2          17.3          32.1            29.3
# 42                       25.1           4.8          17.7             4.3
#
#           RecipeServings  RecipeYield  \
# RecipeId
# 38                   4.0          NaN
# 39                   6.0          NaN
# 40                   4.0          NaN
# 41                   2.0     4 kebabs
# 42                   4.0          NaN
#
#                                          RecipeInstructions
# RecipeId
# 38        c("Toss 2 cups berries with sugar.", "Let stan...
# 39        c("Soak saffron in warm milk for 5 minutes and...
# 40        c("Into a 1 quart Jar with tight fitting lid, ...
# 41        c("Drain the tofu, carefully squeezing out exc...
# 42        c("Mix everything together and bring to a boil...
#
# [5 rows x 27 columns]

# %% [markdown]
# Checkign for null values on the data set

# %%
recipes.isnull().sum()
# Out:
# Name                               0
# AuthorId                           0
# AuthorName                         0
# CookTime                       82545
# PrepTime                           0
# TotalTime                          0
# DatePublished                      0
# Description                        5
# Images                             1
# RecipeCategory                   751
# Keywords                       17237
# RecipeIngredientQuantities         3
# RecipeIngredientParts              0
# AggregatedRating              253223
# ReviewCount                   247489
# Calories                           0
# FatContent                         0
# SaturatedFatContent                0
# CholesterolContent                 0
# SodiumContent                      0
# CarbohydrateContent                0
# FiberContent                       0
# SugarContent                       0
# ProteinContent                     0
# RecipeServings                182911
# RecipeYield                   348071
# RecipeInstructions                 0
# dtype: int64

# %% [markdown]
# Checking the shape and columns of the DataFrame

# %%
recipes.shape
# Out:
# (522517, 27)

# %%
recipes.columns
# Out:
# Index(['Name', 'AuthorId', 'AuthorName', 'CookTime', 'PrepTime', 'TotalTime',
#        'DatePublished', 'Description', 'Images', 'RecipeCategory', 'Keywords',
#        'RecipeIngredientQuantities', 'RecipeIngredientParts',
#        'AggregatedRating', 'ReviewCount', 'Calories', 'FatContent',
#        'SaturatedFatContent', 'CholesterolContent', 'SodiumContent',
#        'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent',
#        'RecipeServings', 'RecipeYield', 'RecipeInstructions'],
#       dtype='object')

# %% [markdown]
# Just double checking the null values on the data set

# %%
recipes.loc[recipes['AggregatedRating'].isnull()]
# Out:
#                                                       Name    AuthorId  \
# RecipeId
# 61                                      Brownie Heart Cake        1555
# 68                                     Chicago Style Pizza      174711
# 69                                          Chicha Peruana        1595
# 74                                Brownie Cheesecake Torte       67395
# 75                                California Chilled Salsa        1551
# ...                                                    ...         ...
# 541379                      Meg's Fresh Ginger Gingerbread  2002090414
# 541380    Roast Prime Rib au Poivre with Mixed Peppercorns      211566
# 541381                               Kirshwasser Ice Cream  2001131545
# 541382            Quick & Easy Asian Cucumber Salmon Rolls  2001004241
# 541383                             Spicy Baked Scotch Eggs      188099
#
#                 AuthorName CookTime PrepTime TotalTime         DatePublished  \
# RecipeId
# 61           Cindy Hartlin    PT42M    PT35M   PT1H17M  1999-09-07T14:15:00Z
# 68        Queen Dragon Mom  PT2H38M    PT35M   PT3H13M  1999-08-22T04:56:00Z
# 69                Enrique1  PT1H50M  PT2H45M   PT4H35M  1999-08-14T06:20:00Z
# 74               Dannygirl    PT55M    PT35M   PT1H30M  1999-08-22T04:49:00Z
# 75              Sean Coate      NaN    PT25M     PT25M  1999-09-06T05:11:00Z
# ...                    ...      ...      ...       ...                   ...
# 541379               rdsxc    PT35M     PT1H   PT1H35M  2020-12-22T15:27:00Z
# 541380        Denver cooks     PT3H    PT30M   PT3H30M  2020-12-22T15:32:00Z
# 541381         Jonathan F.     PT3H     PT1H      PT4H  2020-12-22T15:33:00Z
# 541382           CLUBFOODY      NaN    PT15M     PT15M  2020-12-22T22:11:00Z
# 541383        Chef LauraMD    PT25M    PT15M     PT40M  2020-12-22T22:12:00Z
#
#                                                 Description  \
# RecipeId
# 61        Make and share this Brownie Heart Cake recipe ...
# 68        Make and share this Chicago Style Pizza recipe...
# 69        Chicha (corn beer). Chicha is made in South an...
# 74        Make and share this Brownie Cheesecake Torte r...
# 75        Make and share this California Chilled Salsa r...
# ...                                                     ...
# 541379    Make and share this Meg's Fresh Ginger Gingerb...
# 541380    White, black, green, and pink peppercorns add ...
# 541381    Make and share this Kirshwasser Ice Cream reci...
# 541382    Extremely quick and easy to make, these are gr...
# 541383    Great way to have hard boiled eggs and crispy,...
#
#                                                      Images  RecipeCategory  \
# RecipeId
# 61                                             character(0)         Dessert
# 68                                             character(0)       Weeknight
# 69                                             character(0)       Beverages
# 74        "https://img.sndimg.com/food/image/upload/w_55...      Cheesecake
# 75                                             character(0)          Sauces
# ...                                                     ...             ...
# 541379                                         character(0)         Dessert
# 541380    "https://img.sndimg.com/food/image/upload/w_55...  Very Low Carbs
# 541381                                         character(0)       Ice Cream
# 541382    "https://img.sndimg.com/food/image/upload/w_55...        Canadian
# 541383                                         character(0)       Breakfast
#
#           ... SaturatedFatContent CholesterolContent SodiumContent  \
# RecipeId  ...
# 61        ...               144.2             1097.5        2157.8
# 68        ...                10.1               55.0         990.0
# 69        ...                 0.0                0.0           3.6
# 74        ...                 3.0               15.9         194.7
# 75        ...                 0.0                0.0         354.9
# ...       ...                 ...                ...           ...
# 541379    ...                 7.6               54.4         278.2
# 541380    ...                71.4              433.8         766.3
# 541381    ...                72.6              470.9         192.5
# 541382    ...                 0.1                2.9         100.5
# 541383    ...                22.2             1769.7        1318.6
#
#           CarbohydrateContent  FiberContent  SugarContent  ProteinContent  \
# RecipeId
# 61                      509.9          29.0         392.5            71.7
# 68                       41.1           1.9           2.5            20.9
# 69                        2.7           1.5           0.0             2.7
# 74                       14.4           0.5          10.9             5.7
# 75                        4.9           0.9           3.3             0.6
# ...                       ...           ...           ...             ...
# 541379                   48.5           0.8          22.8             3.9
# 541380                    3.2           0.7           0.1           117.0
# 541381                   33.9           0.0          17.3            12.8
# 541382                    0.3           0.0           0.1             2.4
# 541383                   29.7           1.3           6.7            76.4
#
#           RecipeServings     RecipeYield  \
# RecipeId
# 61                   NaN    1 Large cake
# 68                   8.0        8 slices
# 69                   NaN         1 batch
# 74                  12.0              12
# 75                  10.0             NaN
# ...                  ...             ...
# 541379               8.0  1 8x8 cake pan
# 541380               8.0         1 Roast
# 541381               6.0             NaN
# 541382               NaN        20 rolls
# 541383               NaN             NaN
#
#                                          RecipeInstructions
# RecipeId
# 61        c("CAKE:  Grease 5 cup heart shaped pan; dust ...
# 68        c("For crust, dissolve yeast in water.", "Add ...
# 69        c("Procedure: Mash for 90 minutes at 160°F.", ...
# 74        c("Preheat oven to 425 degrees F.", "Combine f...
# 75        c("* Also delicious made with red sweet pepper...
# ...                                                     ...
# 541379    c("Preheat oven to 350&deg;F Grease an 8x8 cak...
# 541380    c("Position rack in center of oven and preheat...
# 541381    c("heat half and half and heavy cream to a sim...
# 541382    c("In a small bowl, combine mayo and wasabi pa...
# 541383    c("Mix sausage, panko, egg yolk and Wocestersh...
#
# [253223 rows x 27 columns]

# %%
recipes.dropna(subset=['AggregatedRating'], inplace=True)

# %%
recipes.shape
# Out:
# (269294, 27)

# %% [markdown]
# The rest of the columns that have null values will not be used for this recommender system so I will leave them like that.

# %%
recipes.isnull().sum()
# Out:
# Name                               0
# AuthorId                           0
# AuthorName                         0
# CookTime                       42784
# PrepTime                           0
# TotalTime                          0
# DatePublished                      0
# Description                        3
# Images                             1
# RecipeCategory                   245
# Keywords                        6335
# RecipeIngredientQuantities         2
# RecipeIngredientParts              0
# AggregatedRating                   0
# ReviewCount                        0
# Calories                           0
# FatContent                         0
# SaturatedFatContent                0
# CholesterolContent                 0
# SodiumContent                      0
# CarbohydrateContent                0
# FiberContent                       0
# SugarContent                       0
# ProteinContent                     0
# RecipeServings                 96924
# RecipeYield                   186471
# RecipeInstructions                 0
# dtype: int64

# %% [markdown]
# ### Choosing columns for vectorizer
# Below i will just be exploring in depth the columns to see  what they contain, to choose which ne would be better to make a vectorizer and apply the content recommendation system. In the example Below I will just Select a few of them, to see potential candidates.

# %%
top_rated = recipes.sort_values(by=['AggregatedRating', 'ReviewCount'], ascending=False)
core_columns = ['Name', 'Keywords', 'RecipeCategory' ,'AggregatedRating', 'ReviewCount', 'Description', 'RecipeInstructions']
top_rated[['Name', 'Keywords', 'RecipeCategory' ,'AggregatedRating', 'ReviewCount', 'Description', 'RecipeInstructions']].head(10)
# Out:
#                                                       Name  \
# RecipeId
# 45809                                      Bourbon Chicken
# 2886                                     Best Banana Bread
# 27208                           To Die for Crock Pot Roast
# 39087                           Creamy Cajun Chicken Pasta
# 35813                               Oatmeal Raisin Cookies
# 67256     Best Ever Banana Cake With Cream Cheese Frosting
# 54257              Yes, Virginia There is a Great Meatloaf
# 22782                     Jo Mama's World Famous Spaghetti
# 32204      &quot;Whatever Floats Your Boat&quot; Brownies!
# 25690                                             Pancakes
#
#                                                    Keywords  RecipeCategory  \
# RecipeId
# 45809     c("Chicken", "Poultry", "Meat", "Chinese", "As...  Chicken Breast
# 2886              c("Breads", "Fruit", "Oven", "< 4 Hours")    Quick Breads
# 27208     c("Roast Beef", "Meat", "Kid Friendly", "Potlu...   One Dish Meal
# 39087     c("Chicken", "Poultry", "Meat", "Cajun", "Kid ...  Chicken Breast
# 35813     c("Dessert", "Lunch/Snacks", "Cookie & Brownie...    Drop Cookies
# 67256     c("Tropical Fruits", "Fruit", "Weeknight", "Fo...         Dessert
# 54257               c("Meat", "Roast", "Oven", "< 4 Hours")        Meatloaf
# 22782     c("Pork", "Meat", "European", "Kid Friendly", ...       Spaghetti
# 32204     c("Dessert", "Lunch/Snacks", "Cookie & Brownie...      Bar Cookie
# 25690                 c("< 15 Mins", "Easy", "Inexpensive")       Breakfast
#
#           AggregatedRating  ReviewCount  \
# RecipeId
# 45809                  5.0       3063.0
# 2886                   5.0       2273.0
# 27208                  5.0       1692.0
# 39087                  5.0       1586.0
# 35813                  5.0       1410.0
# 67256                  5.0       1409.0
# 54257                  5.0       1384.0
# 22782                  5.0       1326.0
# 32204                  5.0       1284.0
# 25690                  5.0       1150.0
#
#                                                 Description  \
# RecipeId
# 45809     I searched and finally found this recipe on th...
# 2886      Make and share this Best Banana Bread recipe f...
# 27208     Amazing flavor, and so simple! No salt needed ...
# 39087     Make and share this Creamy Cajun Chicken Pasta...
# 35813     You've made oatmeal-raisin cookies before, so ...
# 67256     This is one of (if not) the BEST banana cake I...
# 54257     Absolutely delicious meatloaf and sauce! Those...
# 22782     My kids will give up a steak dinner for this s...
# 32204     These are absolutely the chewiest, moistest, f...
# 25690     This is really a great recipe! It is fast, sim...
#
#                                          RecipeInstructions
# RecipeId
# 45809     c("Editor's Note:  Named Bourbon Chicken becau...
# 2886      c("Remove odd pots and pans from oven.", "Preh...
# 27208     c("Place beef roast in crock pot.", "Mix the d...
# 39087     c("Place chicken and Cajun seasoning in a bowl...
# 35813     c("Preheat oven to 350°.", "Whisk dry ingredie...
# 67256     c("Preheat oven to 275°F (135C).", "Grease and...
# 54257     c("Meatloaf: Combine meat loaf ingredients and...
# 22782     c("In large, heavy stockpot, brown Italian sau...
# 32204     c("Preheat oven to 350°F.", "Grease an 8 inch ...
# 25690     c("Beat egg until fluffy.", "Add milk and melt...

# %% [markdown]
# Checking the top rated `Recipes` (the `AggregatedRating` column) with the most `ReviewCount`

# %%
top_rated[['Name', 'Keywords', 'RecipeCategory' ,'AggregatedRating', 'ReviewCount', 'Description', 'RecipeInstructions']].loc[recipes['ReviewCount']<10]
# Out:
#                                         Name  \
# RecipeId
# 186                           Coca-Cola Cake
# 210                     Christmas Snow Punch
# 221                   Chocolate Chip Muffins
# 270                       Spiced Pear Butter
# 355                              Apple Crisp
# ...                                      ...
# 534266    White Chocolate Peppermint Candies
# 534306                     Crack Green Beans
# 535846                          Creole Gumbo
# 536377              Carrabba's Marsala Sauce
# 536422          Vegetarian French Onion Soup
#
#                                                    Keywords  RecipeCategory  \
# RecipeId
# 186                     c("Weeknight", "Oven", "< 4 Hours")         Dessert
# 210       c("Beverages", "Winter", "Christmas", "< 15 Mi...  Punch Beverage
# 221           c("Breads", "Weeknight", "Oven", "< 4 Hours")    Quick Breads
# 270       c("Fruit", "Weeknight", "Stove Top", "< 4 Hours")           Pears
# 355       c("Apple", "Fruit", "Low Protein", "< 60 Mins"...         Dessert
# ...                                                     ...             ...
# 534266                                          "< 4 Hours"         Dessert
# 534306                        c("Low Protein", "< 60 Mins")       Vegetable
# 535846    c("Chicken", "Poultry", "Meat", "Very Low Carb...           Gumbo
# 536377                   c("European", "< 15 Mins", "Easy")          Sauces
# 536422    c("Egg Free", "Free Of...", "Savory", "Stove T...        European
#
#           AggregatedRating  ReviewCount  \
# RecipeId
# 186                    5.0          9.0
# 210                    5.0          9.0
# 221                    5.0          9.0
# 270                    5.0          9.0
# 355                    5.0          9.0
# ...                    ...          ...
# 534266                 1.0          1.0
# 534306                 1.0          1.0
# 535846                 1.0          1.0
# 536377                 1.0          1.0
# 536422                 1.0          1.0
#
#                                                 Description  \
# RecipeId
# 186       Make and share this Coca-Cola Cake recipe from...
# 210       Here is a punch recipe that we used at my in-l...
# 221       When I find my bananas getting too ripe I free...
# 270       Make and share this Spiced Pear Butter recipe ...
# 355       Make and share this Apple Crisp recipe from Fo...
# ...                                                     ...
# 534266    Make and share this White Chocolate Peppermint...
# 534306    Make and share this Crack Green Beans recipe f...
# 535846    Make and share this Creole Gumbo recipe from F...
# 536377    Carrabba's delicious marsala sauce recipe, str...
# 536422    This recipe of French onion soup is vegetarian...
#
#                                          RecipeInstructions
# RecipeId
# 186       c("Combine flour, sugar, salt, cocoa and bakin...
# 210       c("In punch bowl, combine Hi-C Hula Punch, Spr...
# 221       c("Preheat oven to 400 degrees Fahrenheit.", "...
# 270       c("Combine pears and apple juice in a large Du...
# 355       c("Fill a 6\" x 10\" (I use a 9\" x 13\") baki...
# ...                                                     ...
# 534266    c("Spray the ice cube tray with cooking spray....
# 534306    c("Preheat oven to 350°.", "Drain green beans ...
# 535846    c("Bring water and bay leaves to a boil.", "In...
# 536377    c("Melt 1 tablespoon of the butter in a large ...
# 536422    c("Thinly slice onions into half-moon shapes."...
#
# [242053 rows x 7 columns]

# %% [markdown]
# # Section2
# ## Search
#
# In this section I will work in my search bar. Since I want to be able to use all this code in my rpesentation day, searching will be important. Since it is almost impossible that the user knows exactly the name of a recipe, I will first give them a tool in which they can filter by ingridients, to be able to get recipes names that they can later on use to search for similar recipies.
#
# The problem with the search is that the result is exact. So putting a few ingridients would do the trick. The recommendation result is not exact, it gives a bit more freedom to give recommendations with maybe a few different ingridients, which can wake the curiosity of the user.

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# C:\Users\ajgag\anaconda3\envs\capstone2\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# In the code below I am just looking for recipes that has 'Cheddar' in its ingredients.

# %%
recipes.loc[recipes['RecipeIngredientParts'].str.contains('cheddar')].head(5)
# Out:
#                                        Name  AuthorId          AuthorName  \
# RecipeId
# 102       Cheesy Scalloped Potato Side Dish    125579    GrandmaIsCooking
# 104                  Cheeseburger Casserole      1535  Marg CaymanDesigns
# 108       Buttermilk Pie in Cornmeal Pastry      1535  Marg CaymanDesigns
# 162                         Chicken Lasagna      1562              Libby1
# 208                Chunky Tomato Cheese Pie      1559      Will Parkinson
#
#          CookTime PrepTime TotalTime         DatePublished  \
# RecipeId
# 102       PT1H30M    PT25M   PT1H55M  1999-08-14T20:12:00Z
# 104         PT25M    PT15M     PT40M  1999-08-19T05:30:00Z
# 108         PT40M     PT1H   PT1H40M  1999-08-06T00:41:00Z
# 162          PT2H    PT30M   PT2H30M  1999-09-20T19:42:00Z
# 208         PT40M    PT35M   PT1H15M  1999-09-16T06:01:00Z
#
#                                                 Description  \
# RecipeId
# 102       --Adopted Recipe--\r\nThis is a simple scallop...
# 104       This is popular with the kids especially. My h...
# 108       Make and share this Buttermilk Pie in Cornmeal...
# 162       Make and share this Chicken Lasagna recipe fro...
# 208       Make and share this Chunky Tomato Cheese Pie r...
#
#                                                      Images RecipeCategory  \
# RecipeId
# 102       c("https://img.sndimg.com/food/image/upload/w_...         Potato
# 104       c("https://img.sndimg.com/food/image/upload/w_...         Cheese
# 108                                            character(0)            Pie
# 162                                            character(0)        Chicken
# 208                                            character(0)         Cheese
#
#           ... SaturatedFatContent CholesterolContent SodiumContent  \
# RecipeId  ...
# 102       ...                 6.5               32.3         260.7
# 104       ...                11.3               71.9        1795.1
# 108       ...                 6.6               83.4         323.9
# 162       ...                 4.7               29.4         693.5
# 208       ...                14.0               56.1        1340.5
#
#           CarbohydrateContent  FiberContent  SugarContent  ProteinContent  \
# RecipeId
# 102                      46.0           5.2           4.3            14.2
# 104                      44.8           1.5          12.6            25.5
# 108                      61.8           1.1          40.8            10.6
# 162                      10.9           0.8           3.1            18.1
# 208                      29.4           2.2           5.7            17.6
#
#           RecipeServings  RecipeYield  \
# RecipeId
# 102                  NaN          NaN
# 104                  6.0          NaN
# 108                  8.0          NaN
# 162                  8.0          NaN
# 208                  6.0          NaN
#
#                                          RecipeInstructions
# RecipeId
# 102       c("Layer potatoes, flour, milk, and salt and p...
# 104       c("Combine ground beef and flour in skillet. A...
# 108       c("For Pastry: Sift together flour and salt; s...
# 162       c("Mix filling ingredients in large bowl.", "S...
# 208       c("Preheat oven to 375 degrees Fahrenheit.", "...
#
# [5 rows x 27 columns]

# %% [markdown]
# Then I am adding a level of difficulty on searching 2 ingridients. But this code would not be very effective for multiple items

# %%
recipes.loc[recipes['RecipeIngredientParts'].str.contains('cheddar') & recipes['RecipeIngredientParts'].str.contains('chicken')].head(5)   #looking for columns that has this ingredient
# Out:
#                                              Name  AuthorId        AuthorName  \
# RecipeId
# 162                               Chicken Lasagna      1562            Libby1
# 339                      Spinach Phyllo Casserole     39547          Julesong
# 506       Yummy and Comforting Chicken Tetrazzini     51011       Loves2Teach
# 558                     German Potato-Cheese Soup      1549          Dave5003
# 602                      Enchiladas Verdes Suizas    174711  Queen Dragon Mom
#
#          CookTime PrepTime TotalTime         DatePublished  \
# RecipeId
# 162          PT2H    PT30M   PT2H30M  1999-09-20T19:42:00Z
# 339         PT45M     PT1H   PT1H45M  1999-09-13T03:48:00Z
# 506         PT40M    PT35M   PT1H15M  1999-08-26T03:56:00Z
# 558         PT40M    PT30M   PT1H10M  1999-08-17T04:36:00Z
# 602         PT15M  PT1H20M   PT1H35M  1999-08-25T06:25:00Z
#
#                                                 Description  \
# RecipeId
# 162       Make and share this Chicken Lasagna recipe fro...
# 339       The layers of this low-fat phyllo pastry are c...
# 506       Though very easy, this is surprisingly good.  ...
# 558       Make and share this German Potato-Cheese Soup ...
# 602       For authenticity, substitute crema for the whi...
#
#                                                      Images RecipeCategory  \
# RecipeId
# 162                                            character(0)        Chicken
# 339       c("https://img.sndimg.com/food/image/upload/w_...      Vegetable
# 506                                            character(0)        Chicken
# 558       "https://img.sndimg.com/food/image/upload/w_55...         Potato
# 602                                            character(0)        Mexican
#
#           ... SaturatedFatContent CholesterolContent SodiumContent  \
# RecipeId  ...
# 162       ...                 4.7               29.4         693.5
# 339       ...                 1.9                6.3         319.9
# 506       ...                12.9               56.4         746.8
# 558       ...                 9.7               45.8         775.8
# 602       ...                29.9              152.0         325.8
#
#           CarbohydrateContent  FiberContent  SugarContent  ProteinContent  \
# RecipeId
# 162                      10.9           0.8           3.1            18.1
# 339                       8.7           1.1           0.8            12.7
# 506                      26.7           1.4           3.0            16.2
# 558                      24.2           2.7           5.6            14.3
# 602                      66.5           9.6          10.3            13.6
#
#           RecipeServings    RecipeYield  \
# RecipeId
# 162                  8.0            NaN
# 339                  8.0            NaN
# 506                 10.0            NaN
# 558                 12.0            NaN
# 602                  4.0  12 enchiladas
#
#                                          RecipeInstructions
# RecipeId
# 162       c("Mix filling ingredients in large bowl.", "S...
# 339       c("Preheat oven to 375 F (190 C). Saute onions...
# 506       c("Cook the spaghetti according to package dir...
# 558       c("Peel and prepare vegetables.", "In a large ...
# 602       c("Remove papery husks from tomatillos.", "Was...
#
# [5 rows x 27 columns]

# %% [markdown]
# In the next two block of codes I am just manually searching the ingridients to explore and see if they are atleast similar

# %%
recipes['RecipeIngredientParts'].loc[recipes['Name'] == 'Chicken Lasagna']
# Out:
# RecipeId
# 162       c("onion", "green pepper", "skim milk", "fresh...
# 76476     c("chicken broth", "salt", "cottage cheese", "...
# 87901     c("butter", "milk", "parsley", "parmesan chees...
# 134726    c("butter", "onions", "skinless chicken breast...
# 165926    c("mushrooms", "onion", "oregano", "basil", "m...
# 171715    c("cottage cheese", "cheddar cheese", "parmesa...
# 210101    c("butter", "olive oil", "mushroom", "garlic c...
# 310552    c("butter", "onion", "garlic clove", "all-purp...
# 311199    c("boneless chicken breasts", "cottage cheese"...
# 349042    c("boneless skinless chicken breast", "diced t...
# 357970    c("butter", "flour", "salt", "basil", "chicken...
# 387872    c("chicken breasts", "onion", "bell pepper", "...
# Name: RecipeIngredientParts, dtype: object

# %%
# exploring the ingridientsParts

# So i can see the whole column
pd.set_option('display.max_colwidth', None)

# Access the recipe i want to see
print(recipes['RecipeIngredientParts'].loc[recipes['Name'] == 'Chicken Lasagna'])

# setting the reset back to normal
pd.reset_option('display.max_colwidth')
# Out:
# RecipeId
# 162                                                                                             c("onion", "green pepper", "skim milk", "fresh mushrooms", "pimiento", "dried basil", "nonfat cottage cheese", "mozzarella cheese", "parmesan cheese", "chicken", "cheddar cheese")
# 76476                                                                                                                                  c("chicken broth", "salt", "cottage cheese", "cream cheese", "sour cream", "mayonnaise", "onion", "green pepper", "fresh parsley", "butter")
# 87901                                                                                                                        c("butter", "milk", "parsley", "parmesan cheese", "onion", "cottage cheese", "cheddar cheese", "cream cheese", "mozzarella cheese", "frozen broccoli")
# 134726                                                                                                                                     c("butter", "onions", "skinless chicken breast", "salt", "pepper", "asparagus", "cheddar cheese", "parmesan cheese", "basil", "oregano")
# 165926                                                                                                                                                                                          c("mushrooms", "onion", "oregano", "basil", "mozzarella cheese", "parmesan cheese")
# 171715                                                                                                             c("cottage cheese", "cheddar cheese", "parmesan cheese", "butter", "onion", "green pepper", "flour", "chicken broth", "milk", "pimiento", "basil", "white wine")
# 210101                                                    c("butter", "olive oil", "mushroom", "garlic cloves", "fresh parsley", "flour", "milk", "chicken broth", "salt", "white pepper", "half-and-half", "prosciutto", "ricotta cheese", "mozzarella cheese", "parmesan cheese")
# 310552    c("butter", "onion", "garlic clove", "all-purpose flour", "salt", "chicken broth", "milk", "mozzarella cheese", "parmesan cheese", "dried basil", "dried oregano", "ground black pepper", "ricotta cheese", "frozen chopped spinach", "fresh parsley", "parmesan cheese")
# 311199                                                                                                                                                               c("boneless chicken breasts", "cottage cheese", "milk", "cream cheese", "mozzarella cheese", "cheddar cheese")
# 349042          c("boneless skinless chicken breast", "diced tomatoes", "tomato paste", "fresh mushrooms", "onion", "dried basil", "salt", "garlic powder", "2% fat cottage cheese", "egg substitute", "parmesan cheese", "fresh parsley", "pepper", "part-skim mozzarella cheese")
# 357970                                                                                                                                                      c("butter", "flour", "salt", "basil", "chicken broth", "cottage cheese", "egg", "mozzarella cheese", "parmesan cheese")
# 387872                       c("chicken breasts", "onion", "bell pepper", "butter", "garlic cloves", "half-and-half", "flour", "chicken bouillon cubes", "romano cheese", "monterey jack cheese", "parmesan cheese", "colby-monterey jack cheese", "white pepper", "garlic powder")
# Name: RecipeIngredientParts, dtype: object

# %% [markdown]
# Well, now that the manual search is kind of ok, I will tune it up make it better

# %% [markdown]
# I will try out a way to search recipes based on Ingridients. Right now I am doing it like this, later on I will try doing a function. The reason I am doing this is because it will be difficult for people to know the exact name of the Recipe they are looking for, so to make their life easier, I want them to be able to look by keywords (in this case ingridients), get a list of recipies that have these ingridients, and with that list, be able to copy them to the `Content Recommender` (function) which will recommend similar recipes.

# %%
# searching for ingridients
ingredients = ['cheddar', 'chicken', 'garlic', 'spaghetti']  

mask = True  

for ingredient in ingredients:
    mask = mask & recipes['RecipeIngredientParts'].str.contains(ingredient)

result = recipes.loc[mask]

result
# Out:
#                                                      Name  AuthorId  \
# RecipeId
# 23700            Baked Spaghetti With Chicken and Spinach      5060
# 52978                                Spaghetti Squash Ole     54716
# 82638                                   Mexican Spaghetti     67573
# 116815               Kittencal's Tuna-Spaghetti Casserole     89831
# 137226                   Chicken Spaghetti Casserole Bake     89831
# 154183          Creamy Turkey (Or Chicken) Spaghetti Bake     89831
# 184052             Rotisserie Chicken Spaghetti Casserole     27783
# 184922                           Stuffed Spaghetti Squash    123118
# 231284                                 Chicken Tetrazzini    384737
# 330414                          Cheesy Chicken Tetrazzini    226863
# 343134    Baked Spaghetti Squash With Chicken and Veggies    138429
# 350437                                   Cincinnati Chili    736554
# 479680                          Patrick's Baked Spaghetti    196369
#
#                    AuthorName CookTime PrepTime TotalTime  \
# RecipeId
# 23700                Derf2440    PT30M    PT15M     PT45M
# 52978             Mimi Bobeck  PT1H10M    PT10M   PT1H20M
# 82638               TPubmgjbd    PT40M    PT15M     PT55M
# 116815    Kittencalrecipezazz    PT30M    PT30M      PT1H
# 137226    Kittencalrecipezazz    PT40M    PT30M   PT1H10M
# 154183    Kittencalrecipezazz    PT30M    PT30M      PT1H
# 184052         HeatherFeather    PT45M    PT15M      PT1H
# 184922                 momjan    PT45M    PT30M   PT1H15M
# 231284    Salt Lake Meal Swap    PT30M    PT30M      PT1H
# 330414             breezermom     PT1H    PT10M   PT1H10M
# 343134                 Dotty2  PT1H10M    PT20M   PT1H30M
# 350437              happynana  PT1H30M    PT30M      PT2H
# 479680               Bone Man    PT40M    PT30M   PT1H10M
#
#                  DatePublished  \
# RecipeId
# 23700     2002-03-28T17:10:00Z
# 52978     2003-02-02T20:11:00Z
# 82638     2004-01-31T20:01:00Z
# 116815    2005-04-12T16:47:00Z
# 137226    2005-09-13T11:52:00Z
# 154183    2006-02-01T14:04:00Z
# 184052    2006-08-31T13:26:00Z
# 184922    2006-09-06T21:28:00Z
# 231284    2007-05-30T17:03:00Z
# 330414    2008-10-13T23:57:00Z
# 343134    2008-12-11T21:39:00Z
# 350437    2009-01-18T02:42:00Z
# 479680    2012-05-21T10:48:00Z
#
#                                                 Description  \
# RecipeId
# 23700     One of our favourite ways to serve spaghetti, ...
# 52978     Make and share this Spaghetti Squash Ole recip...
# 82638     A good way to use up leftover rotisserie chick...
# 116815    This is a recipe I developed years ago; it als...
# 137226    Make and share this Chicken Spaghetti Casserol...
# 154183    This is a wonderful dish to use up any leftove...
# 184052    This is one of those casseroles with many vers...
# 184922    A really good recipe, low cal, lots of veggies...
# 231284    Make and share this Chicken Tetrazzini recipe ...
# 330414    This recipe came from Southern Living, way bac...
# 343134    A recipe that is enjoyed at out house.  Great ...
# 350437    From Cooks Illustrated.  We tried this tonight...
# 479680    This is a very rich and creamy, non-tomatoey, ...
#
#                                                      Images   RecipeCategory  \
# RecipeId
# 23700     "https://img.sndimg.com/food/image/upload/w_55...    One Dish Meal
# 52978                                          character(0)  Low Cholesterol
# 82638     "https://img.sndimg.com/food/image/upload/w_55...          Chicken
# 116815    c("https://img.sndimg.com/food/image/upload/w_...             Tuna
# 137226                                         character(0)        Spaghetti
# 154183                                         character(0)        Spaghetti
# 184052                                         character(0)          Chicken
# 184922                                         character(0)    One Dish Meal
# 231284                                         character(0)    One Dish Meal
# 330414    c("https://img.sndimg.com/food/image/upload/w_...        Spaghetti
# 343134    c("https://img.sndimg.com/food/image/upload/w_...    One Dish Meal
# 350437                                         character(0)        Spaghetti
# 479680    "https://img.sndimg.com/food/image/upload/w_55...             Meat
#
#           ... SaturatedFatContent CholesterolContent SodiumContent  \
# RecipeId  ...
# 23700     ...                14.3              138.2        1469.3
# 52978     ...                 3.2               71.0         799.6
# 82638     ...                 9.2               40.1         801.5
# 116815    ...                14.2              136.9         724.6
# 137226    ...                 4.5               18.0         606.9
# 154183    ...                38.9              248.7        1601.4
# 184052    ...                 7.9               76.1         708.3
# 184922    ...                12.8              106.8         682.2
# 231284    ...                11.2              104.5        1043.6
# 330414    ...                22.0              147.6        1228.4
# 343134    ...                16.6              139.4         636.6
# 350437    ...                16.7              133.2        1703.1
# 479680    ...                13.3               92.2        1284.8
#
#           CarbohydrateContent  FiberContent  SugarContent  ProteinContent  \
# RecipeId
# 23700                    65.6           5.7          11.5            57.9
# 52978                    32.1           7.0           6.2            26.4
# 82638                    47.6           4.5           7.9            14.9
# 116815                   40.8           2.5           3.7            31.2
# 137226                   33.0           3.8           6.2            11.6
# 154183                  109.6           8.4          10.3            75.7
# 184052                   35.6           1.6           4.8            25.5
# 184922                   16.0           3.3           8.7            30.1
# 231284                   34.1           1.8           4.0            31.1
# 330414                   37.5           2.8           3.2            46.1
# 343134                   13.5           2.0           4.4            41.3
# 350437                   94.5          11.3          12.8            55.8
# 479680                   58.0           4.8           6.8            33.2
#
#           RecipeServings  RecipeYield  \
# RecipeId
# 23700                2.0          NaN
# 52978                6.0          NaN
# 82638                6.0          NaN
# 116815               NaN          NaN
# 137226               6.0          NaN
# 154183               NaN          NaN
# 184052              12.0          NaN
# 184922               4.0      2 boats
# 231284              10.0          NaN
# 330414               NaN          NaN
# 343134               4.0          NaN
# 350437               NaN          NaN
# 479680               8.0  1 casserole
#
#                                          RecipeInstructions
# RecipeId
# 23700     c("Cook spaghetti, al dente, drain and set asi...
# 52978     c("Halve the spaghetti squash lengthwise and r...
# 82638     c("In a large skillet, saute onion and garlic ...
# 116815    c("Butter a 13 x 9-inch baking dish.", "Chop t...
# 137226    c("Set oven to 350 degrees F.", "Butter a 3-qu...
# 154183    c("In a large heavy saucepan cook the fresh mu...
# 184052    c("Remove skin and bones from your rotisserie ...
# 184922    c("Pierce the squash along one side in a strai...
# 231284    c("Assembly Directions:", "Break the noodles i...
# 330414    c("Combine first 3 ingredients in a saucepan;b...
# 343134    c("Preheat oven to 375°F.", "Place squash on a...
# 350437    c("FOR THE CHILI:", "Bring 2 quarts of water a...
# 479680    c("Pre-heat the oven to 350-degrees F.", "In a...
#
# [13 rows x 27 columns]

# %% [markdown]
# `RecipeIngredientParts` seems like a good candidate to make the vectorizer.
#
# Next I will analyze `RecipeInstructions` to see what kind of data it contains.

# %%
# searching for ingridients using the 'RecipeInstructions' column
ingredients = ['cheddar', 'chicken', 'garlic', 'spaghetti']  

mask = True  

for ingredient in ingredients:
    mask = mask & recipes['RecipeInstructions'].str.contains(ingredient)

result = recipes.loc[mask]

result
# Out:
#                                                       Name  AuthorId  \
# RecipeId
# 94519                                Creole Spaghetti Bake     89831
# 116815                Kittencal's Tuna-Spaghetti Casserole     89831
# 133250               Ospidillo Cafe Cincinnati Chili No. 2    196369
# 137226                    Chicken Spaghetti Casserole Bake     89831
# 214724                                    Cincinnati Chili    398160
# 218790    Cowboy Spaghetti With Cheese Sauce - Rachael Ray    170628
# 219206                            Creamy Chicken Spaghetti     88099
# 231284                                  Chicken Tetrazzini    384737
# 277393         Nimz's Creamy Chicken Spaghetti (Lite-Bleu)    452940
# 316545      Chili Sauce for Hot Dogs, Fries and Hamburgers    795588
# 403512                        Chicken or Turkey Tetrazzini   1072593
# 415326              Chicken Tetrazzini With Cheddar Cheese     37779
# 479680                           Patrick's Baked Spaghetti    196369
#
#                    AuthorName CookTime PrepTime TotalTime  \
# RecipeId
# 94519     Kittencalrecipezazz    PT25M    PT30M     PT55M
# 116815    Kittencalrecipezazz    PT30M    PT30M      PT1H
# 133250               Bone Man     PT6H     PT1H      PT7H
# 137226    Kittencalrecipezazz    PT40M    PT30M   PT1H10M
# 214724      GREG IN SAN DIEGO    PT20M    PT20M     PT40M
# 218790               LizP5885      NaN    PT45M     PT45M
# 219206                  Nimz_    PT45M    PT40M   PT1H25M
# 231284    Salt Lake Meal Swap    PT30M    PT30M      PT1H
# 277393                  2Bleu  PT1H30M    PT40M   PT2H10M
# 316545               Brandess     PT2H     PT5M    PT2H5M
# 403512               gailanng    PT30M    PT25M     PT55M
# 415326        ratherbeswimmin    PT20M     PT1H   PT1H20M
# 479680               Bone Man    PT40M    PT30M   PT1H10M
#
#                  DatePublished  \
# RecipeId
# 94519     2004-06-28T20:00:00Z
# 116815    2005-04-12T16:47:00Z
# 133250    2005-08-11T19:54:00Z
# 137226    2005-09-13T11:52:00Z
# 214724    2007-03-02T22:23:00Z
# 218790    2007-03-25T20:40:00Z
# 219206    2007-03-27T22:20:00Z
# 231284    2007-05-30T17:03:00Z
# 277393    2008-01-08T00:19:00Z
# 316545    2008-07-30T19:11:00Z
# 403512    2009-12-13T22:34:00Z
# 415326    2010-03-04T06:39:00Z
# 479680    2012-05-21T10:48:00Z
#
#                                                 Description  \
# RecipeId
# 94519     Make and share this Creole Spaghetti Bake reci...
# 116815    This is a recipe I developed years ago; it als...
# 133250    If you've ever eaten &quot;Cincinnati Chili&qu...
# 137226    Make and share this Chicken Spaghetti Casserol...
# 214724    This recipe came from a recent edition of &quo...
# 218790    I saw Rachael Ray make this on her show and I ...
# 219206    This is so rich and creamy with a hint of spic...
# 231284    Make and share this Chicken Tetrazzini recipe ...
# 277393    This is a healthier version of Chef #88099's R...
# 316545    This is 1 of my 2 staple chili sauces. This is...
# 403512    Sometimes we just need simple.  Good use for l...
# 415326    Make and share this Chicken Tetrazzini With Ch...
# 479680    This is a very rich and creamy, non-tomatoey, ...
#
#                                                      Images RecipeCategory  \
# RecipeId
# 94519                                          character(0)      Spaghetti
# 116815    c("https://img.sndimg.com/food/image/upload/w_...           Tuna
# 133250    c("https://img.sndimg.com/food/image/upload/w_...          Beans
# 137226                                         character(0)      Spaghetti
# 214724    c("https://img.sndimg.com/food/image/upload/w_...           Meat
# 218790    c("https://img.sndimg.com/food/image/upload/w_...           Stew
# 219206    c("https://img.sndimg.com/food/image/upload/w_...  One Dish Meal
# 231284                                         character(0)  One Dish Meal
# 277393    "https://img.sndimg.com/food/image/upload/w_55...        Chicken
# 316545    c("https://img.sndimg.com/food/image/upload/w_...         Sauces
# 403512    c("https://img.sndimg.com/food/image/upload/w_...  One Dish Meal
# 415326                                         character(0)           Oven
# 479680    "https://img.sndimg.com/food/image/upload/w_55...           Meat
#
#           ... SaturatedFatContent CholesterolContent SodiumContent  \
# RecipeId  ...
# 94519     ...                11.5               50.0        1047.1
# 116815    ...                14.2              136.9         724.6
# 133250    ...                 2.6               25.0         301.8
# 137226    ...                 4.5               18.0         606.9
# 214724    ...                 3.1               70.3        1214.7
# 218790    ...                13.3               88.8         731.7
# 219206    ...                13.5              103.4        1702.3
# 231284    ...                11.2              104.5        1043.6
# 277393    ...                 5.4               57.9         939.6
# 316545    ...                 2.5               38.1         449.8
# 403512    ...                 9.2               66.1         673.1
# 415326    ...                14.2               88.1         762.5
# 479680    ...                13.3               92.2        1284.8
#
#           CarbohydrateContent  FiberContent  SugarContent  ProteinContent  \
# RecipeId
# 94519                   123.2           7.2          10.8            32.2
# 116815                   40.8           2.5           3.7            31.2
# 133250                   11.8           3.6           1.9            10.8
# 137226                   33.0           3.8           6.2            11.6
# 214724                   15.1           3.5           7.6            28.0
# 218790                   54.7           3.8           5.8            31.4
# 219206                   41.0           2.9           5.5            35.7
# 231284                   34.1           1.8           4.0            31.1
# 277393                   33.2           2.2           5.8            23.9
# 316545                    5.9           1.2           2.8            13.3
# 403512                   27.4           1.1           2.2            24.3
# 415326                   40.5           5.0           4.4            31.8
# 479680                   58.0           4.8           6.8            33.2
#
#           RecipeServings  RecipeYield  \
# RecipeId
# 94519                6.0          NaN
# 116815               NaN          NaN
# 133250              25.0          NaN
# 137226               6.0          NaN
# 214724               NaN          NaN
# 218790               8.0          NaN
# 219206               NaN          NaN
# 231284              10.0          NaN
# 277393               6.0          NaN
# 316545               NaN          NaN
# 403512               6.0          NaN
# 415326               8.0          NaN
# 479680               8.0  1 casserole
#
#                                          RecipeInstructions
# RecipeId
# 94519     c("Set oven to 350 degrees.", "Grease a 2-quar...
# 116815    c("Butter a 13 x 9-inch baking dish.", "Chop t...
# 133250    c("In a large cooking pot, over medium-high  h...
# 137226    c("Set oven to 350 degrees F.", "Butter a 3-qu...
# 214724    c("Heat oil in Dutch oven over medium-high hea...
# 218790    c("Bring a pot of water to a boil. Add a gener...
# 219206    c("Saute onion, peppers and garlic in 1 tables...
# 231284    c("Assembly Directions:", "Break the noodles i...
# 277393    c("In a large skillet over medium heat, melt t...
# 316545    c("With your clean hands start by adding 4 cup...
# 403512    c("Preheat oven 350 degrees and grease a 2 qua...
# 415326    c("Preheat oven to 375°; coat a 3 quart baking...
# 479680    c("Pre-heat the oven to 350-degrees F.", "In a...
#
# [13 rows x 27 columns]

# %% [markdown]
# I was checking if i would get more rows with `Recipe instructions` but it was the same quantity of rows as `RecipeIngridientsParts`

# %%
# searching for ingridients
ingredients = ['cheddar', 'chicken', 'garlic', 'spaghetti']  

mask = True  

for ingredient in ingredients:
    mask = mask & recipes['Description'].str.contains(ingredient)

result = recipes.loc[mask]

result
# Out:
#                               Name  AuthorId AuthorName CookTime PrepTime  \
# RecipeId
# 73376     Very Cheesy Garlic Bread     63098    Shawn C    PT15M     PT5M
#
#          TotalTime         DatePublished  \
# RecipeId
# 73376        PT20M  2003-10-15T20:00:00Z
#
#                                                 Description        Images  \
# RecipeId
# 73376     I love this with my homemade lasagna or spaghe...  character(0)
#
#          RecipeCategory  ... SaturatedFatContent CholesterolContent  \
# RecipeId                 ...
# 73376            Breads  ...                16.7               68.3
#
#          SodiumContent  CarbohydrateContent  FiberContent  SugarContent  \
# RecipeId
# 73376            982.1                 60.0           3.5           0.4
#
#           ProteinContent  RecipeServings  RecipeYield  \
# RecipeId
# 73376               13.6             4.0          NaN
#
#                                          RecipeInstructions
# RecipeId
# 73376     c("Preheat oven to 375°F.", "Cut slices down t...
#
# [1 rows x 27 columns]

# %% [markdown]
# The `description` seems  abit less accurrate. In the example where i did 'cheddar', 'chicken', 'garlic', 'spaghetti' , the `description` only gave me 1 result, so I will not use this one for my searchbar. The one I will use is the ingridients, since it has the words that I need to make a good content-based recommendation system.
#
# Below I will just be exploring the data.

# %%
recipes['RecipeInstructions'].isna().sum()
# Out:
# 0

# %%
recipes.shape
# Out:
# (269294, 27)

# %%
recipes['ReviewCount'].value_counts().head(10)
# Out:
# 1.0     101665
# 2.0      52906
# 3.0      29880
# 4.0      18691
# 5.0      12814
# 6.0       9449
# 7.0       7156
# 8.0       5336
# 9.0       4156
# 10.0      3222
# Name: ReviewCount, dtype: int64

# %% [markdown]
# There are many recipes that have less than 10 reviews. This would be biase reviews so I will get ride of them. Warning. In this case I only do this because I need to make my dataset lot smaller since my computer cant handle the whole dataset and this will be a standalone project. On real life scenarios, keeping them could help this recipes with no reviews have more views and visits.

# %%
recipes = recipes[recipes['ReviewCount'] >= 10]

# %%
recipes.shape
# Out:
# (27241, 27)

# %%
recipes.head(5)
# Out:
#                               Name  AuthorId          AuthorName CookTime  \
# RecipeId
# 40                   Best Lemonade      1566      Stephen Little     PT5M
# 42                    Cabbage Soup      1538           Duckie067    PT30M
# 44          Warm Chicken A La King      1596       Joan Edington     PT3M
# 49        Chicken Breasts Lombardi    174711    Queen Dragon Mom    PT30M
# 54                     Carrot Cake      1535  Marg CaymanDesigns    PT50M
#
#          PrepTime TotalTime         DatePublished  \
# RecipeId
# 40          PT30M     PT35M  1999-09-05T19:52:00Z
# 42          PT20M     PT50M  1999-09-19T06:19:00Z
# 44          PT35M     PT38M  1999-09-17T04:47:00Z
# 49          PT45M   PT1H15M  1999-08-14T19:58:00Z
# 54          PT45M   PT1H35M  1999-09-13T15:20:00Z
#
#                                                 Description  \
# RecipeId
# 40        This is from one of my  first Good House Keepi...
# 42        Make and share this Cabbage Soup recipe from F...
# 44        I copied this one out of a friend's book so ma...
# 49        Make and share this Chicken Breasts Lombardi r...
# 54        This is one of the few recipes my husband ever...
#
#                                                      Images  RecipeCategory  \
# RecipeId
# 40        c("https://img.sndimg.com/food/image/upload/w_...       Beverages
# 42        "https://img.sndimg.com/food/image/upload/w_55...       Vegetable
# 44        "https://img.sndimg.com/food/image/upload/w_55...         Chicken
# 49        c("https://img.sndimg.com/food/image/upload/w_...  Chicken Breast
# 54        c("https://img.sndimg.com/food/image/upload/w_...         Dessert
#
#           ... SaturatedFatContent CholesterolContent SodiumContent  \
# RecipeId  ...
# 40        ...                 0.0                0.0           1.8
# 42        ...                 0.1                0.0         959.3
# 44        ...                31.9              405.8         557.2
# 49        ...                13.0              203.0         848.9
# 54        ...                 4.9               69.8         534.8
#
#           CarbohydrateContent  FiberContent  SugarContent  ProteinContent  \
# RecipeId
# 40                       81.5           0.4          77.2             0.3
# 42                       25.1           4.8          17.7             4.3
# 44                       29.1           3.1           5.0            45.3
# 49                       13.7           0.6           2.0            57.9
# 54                       67.0           1.6          47.9             5.0
#
#           RecipeServings  RecipeYield  \
# RecipeId
# 40                   4.0          NaN
# 42                   4.0          NaN
# 44                   2.0          NaN
# 49                   6.0          NaN
# 54                  12.0      1 bundt
#
#                                          RecipeInstructions
# RecipeId
# 40        c("Into a 1 quart Jar with tight fitting lid, ...
# 42        c("Mix everything together and bring to a boil...
# 44        c("Melt 1 1/2 ozs butter, add the flour and co...
# 49        c("Cook mushrooms in 2 tbsp butter in a large ...
# 54        c("Beat together the eggs, oil, and white suga...
#
# [5 rows x 27 columns]

# %%
recipes['AggregatedRating'].value_counts()
# Out:
# 5.0    21779
# 4.5     4805
# 4.0      553
# 3.5       78
# 3.0       15
# 2.5        7
# 2.0        2
# 1.5        2
# Name: AggregatedRating, dtype: int64

# %% [markdown]
# Again, this is just for demostration porpuses and to make my DataFrame a little bit  smaller (and avoid having a bunch of unrated recipes on my sample).

# %%
recipes = recipes[recipes['AggregatedRating']> 3.5]

# %%
recipes2 = recipes[['Name', 'Images','RecipeIngredientParts']]

# %%
recipes2.head(2)
# Out:
#                    Name                                             Images  \
# RecipeId
# 40        Best Lemonade  c("https://img.sndimg.com/food/image/upload/w_...
# 42         Cabbage Soup  "https://img.sndimg.com/food/image/upload/w_55...
#
#                                       RecipeIngredientParts
# RecipeId
# 40        c("sugar", "lemons, rind of", "lemon, zest of"...
# 42        c("plain tomato juice", "cabbage", "onion", "c...

# %%
recipes2.to_csv('streamlit_files/good_rated_recipes.csv', index=False)

# %%
recipes.shape
# Out:
# (27137, 27)

# %% [markdown]
# I only mantain recipes that are above 3.5 to only recommend the best ones. Since the ones on 3.5 nd bellow are less than 110, it is not a problem.

# %% [markdown]
# # function for search bar

# %% [markdown]
# In the examples below I will search 'cheddar, spaghetti, chicken, garlic' . I did the search to be able to use it later on and I hav ebeen using it a lot to see if the code is correct by searching certain ingredients and see if most of the reocmmendations come up.

# %%
input_ingredients = input('Enter your ingredients, separated by commas: ')
ingredients = input_ingredients.split(',')

mask = True

for ingredient in ingredients:
    mask = mask & recipes['RecipeIngredientParts'].str.contains(ingredient.strip(), case=False)

result = recipes.loc[mask].head(3)

display(result)
# Out:
# Enter your ingredients, separated by commas: cheddar, spaghetti, chicken, garlic
#                                               Name  AuthorId  \
# RecipeId
# 23700     Baked Spaghetti With Chicken and Spinach      5060
# 116815        Kittencal's Tuna-Spaghetti Casserole     89831
#
#                    AuthorName CookTime PrepTime TotalTime  \
# RecipeId
# 23700                Derf2440    PT30M    PT15M     PT45M
# 116815    Kittencalrecipezazz    PT30M    PT30M      PT1H
#
#                  DatePublished  \
# RecipeId
# 23700     2002-03-28T17:10:00Z
# 116815    2005-04-12T16:47:00Z
#
#                                                 Description  \
# RecipeId
# 23700     One of our favourite ways to serve spaghetti, ...
# 116815    This is a recipe I developed years ago; it als...
#
#                                                      Images RecipeCategory  \
# RecipeId
# 23700     "https://img.sndimg.com/food/image/upload/w_55...  One Dish Meal
# 116815    c("https://img.sndimg.com/food/image/upload/w_...           Tuna
#
#           ... SaturatedFatContent CholesterolContent SodiumContent  \
# RecipeId  ...
# 23700     ...                14.3              138.2        1469.3
# 116815    ...                14.2              136.9         724.6
#
#           CarbohydrateContent  FiberContent  SugarContent  ProteinContent  \
# RecipeId
# 23700                    65.6           5.7          11.5            57.9
# 116815                   40.8           2.5           3.7            31.2
#
#           RecipeServings  RecipeYield  \
# RecipeId
# 23700                2.0          NaN
# 116815               NaN          NaN
#
#                                          RecipeInstructions
# RecipeId
# 23700     c("Cook spaghetti, al dente, drain and set asi...
# 116815    c("Butter a 13 x 9-inch baking dish.", "Chop t...
#
# [2 rows x 27 columns]

# %% [markdown]
# Since the code above is working, I did a function to be able to use it later on the presentation day.

# %%
def ingredient_search(recipes):
    input_ingredients = input('Enter your ingredients, separated by commas: ')
    ingredients = input_ingredients.split(',')

    mask = True

    for ingredient in ingredients:
        mask = mask & recipes['RecipeIngredientParts'].str.contains(ingredient.strip(), case=False)

    result = recipes.loc[mask]
    
    return result['Name'].head(10)

# %%
search_result = ingredient_search(recipes)

# Print the search result
display(search_result)
# Out:
# Enter your ingredients, separated by commas: cheddar, spaghetti, chicken, garlic
# RecipeId
# 23700     Baked Spaghetti With Chicken and Spinach
# 116815        Kittencal's Tuna-Spaghetti Casserole
# Name: Name, dtype: object

# %% [markdown]
# The searchbar is working! this will be useful for presentation purpose and here on the code it was very useful to correct my code (i used it many times to see if the recommender at the end is working correctly)

# %% [markdown]
# # Section3
# ## Vectorize for recommendation

# %% [markdown]
# In this part I will vectorize using TfidfVectorizer to make recommendations based on content. First I will have to reset my index to be able to use '.index' I was testing without resenting my index and it was giving me a bunch of problems, so resetting is the way.

# %%
recipes.reset_index(inplace=True)
recipes.head(3)
# Out:
#    RecipeId                    Name  AuthorId      AuthorName CookTime  \
# 0        40           Best Lemonade      1566  Stephen Little     PT5M
# 1        42            Cabbage Soup      1538       Duckie067    PT30M
# 2        44  Warm Chicken A La King      1596   Joan Edington     PT3M
#
#   PrepTime TotalTime         DatePublished  \
# 0    PT30M     PT35M  1999-09-05T19:52:00Z
# 1    PT20M     PT50M  1999-09-19T06:19:00Z
# 2    PT35M     PT38M  1999-09-17T04:47:00Z
#
#                                          Description  \
# 0  This is from one of my  first Good House Keepi...
# 1  Make and share this Cabbage Soup recipe from F...
# 2  I copied this one out of a friend's book so ma...
#
#                                               Images  ... SaturatedFatContent  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  ...                 0.0
# 1  "https://img.sndimg.com/food/image/upload/w_55...  ...                 0.1
# 2  "https://img.sndimg.com/food/image/upload/w_55...  ...                31.9
#
#   CholesterolContent SodiumContent CarbohydrateContent  FiberContent  \
# 0                0.0           1.8                81.5           0.4
# 1                0.0         959.3                25.1           4.8
# 2              405.8         557.2                29.1           3.1
#
#    SugarContent  ProteinContent  RecipeServings  RecipeYield  \
# 0          77.2             0.3             4.0          NaN
# 1          17.7             4.3             4.0          NaN
# 2           5.0            45.3             2.0          NaN
#
#                                   RecipeInstructions
# 0  c("Into a 1 quart Jar with tight fitting lid, ...
# 1  c("Mix everything together and bring to a boil...
# 2  c("Melt 1 1/2 ozs butter, add the flour and co...
#
# [3 rows x 28 columns]

# %% [markdown]
# I used a TFidfVectorizer. I selecte a minimun of 20 words, Because I want to avoid typos or words that are barely used since this could mess up with my model. I also selected a max_df of 0.7 just in case some word is used way too much

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words = "english", min_df=20, max_df = 0.7)
recipes['RecipeIngredientParts'] = recipes['RecipeIngredientParts'].fillna("")

TF_IDF_matrix = vectorizer.fit_transform(recipes['RecipeIngredientParts'])

# %%
TF_IDF_matrix.shape
# Out:
# (27137, 660)

# %%
TF_IDF_matrix
# Out:
# <27137x660 sparse matrix of type '<class 'numpy.float64'>'
# 	with 320380 stored elements in Compressed Sparse Row format>

# %%
import joblib

# %%
joblib.dump(TF_IDF_matrix, 'pkl/tfidf_content_matrix.pkl')
# Out:
# ['pkl/tfidf_content_matrix.pkl']

# %% [markdown]
# # Section4
# ## Recommender

# %% [markdown]
# Now the part where I put all together to create the recommender. First I have to import cosine_similarity and I will test 2 recipes I got from the search, that SHOULD be similar

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# checking the ingridients of 2 recipes
# So i can see the whole column
pd.set_option('display.max_colwidth', None)

print(recipes['RecipeIngredientParts'][recipes['Name'] == 'Warm Chicken A La King'])
print(recipes['RecipeIngredientParts'][recipes['Name'] == 'Chicken Breasts Lombardi'])


# setting the reset back to normal
pd.reset_option('display.max_colwidth')
# Out:
# 2    c("chicken", "butter", "flour", "milk", "celery", "button mushrooms", "green pepper", "canned pimiento", "salt", "black pepper", "Worcestershire sauce", "parsley")
# Name: RecipeIngredientParts, dtype: object
# 3    c("fresh mushrooms", "butter", "boneless skinless chicken breast halves", "flour", "butter", "marsala", "chicken broth", "salt", "mozzarella cheese", "parmesan cheese", "green onion")
# Name: RecipeIngredientParts, dtype: object

# %% [markdown]
# The 2 tested recipes seem kind of similar, but when checking the ingredients, they only have chicken, butter, salt in common, then the others are pretty much different. They had the ingridients I searched for in one of my searches, but... are they really the closest in similarity?
#
# I did a cosine similarity to check it out

# %%
# comparing cosine_similarity of the 2 recipes
recipe_1_index = recipes[recipes['Name'] == 'Warm Chicken A La King'].index[0]  
recipe_2_index = recipes[recipes['Name'] == 'Chicken Breasts Lombardi'].index[0]  

recipe_1 = TF_IDF_matrix[recipe_1_index, :]
recipe_2 = TF_IDF_matrix[recipe_2_index, :]

similarity = cosine_similarity(recipe_1, recipe_2)
print("Similarity:", similarity[0][0])
# Out:
# Similarity: 0.22913068557345473

# %% [markdown]
# The simiarity is 0.22, is that high? low? is it the closes recipe to it? We dont know unless I make the model run through all recipes to see which one has the closes similarity score.

# %%
similarities = cosine_similarity(TF_IDF_matrix, dense_output=False)
similarities.shape
# Out:
# (27137, 27137)

# %%
recipes[recipes['Name'] == 'Warm Chicken A La King'].index
# Out:
# Int64Index([2], dtype='int64')

# %% [markdown]
# Next I will be doing a Dataframe with the recipe name and similarity to see if I get recipes that are actually similar. This is the moment of thuth!

# %%
# Get the column based on the index
recipe_index = recipes[recipes['Name'] == 'Warm Chicken A La King'].index

# Create a dataframe with the recipe titles
sim_df = pd.DataFrame({'RecipeName':recipes['Name'], 
                       'similarity': np.array(similarities[recipe_index, :].todense()).squeeze(),
                      'Ingredients': recipes['RecipeIngredientParts']})

# %%
    sim_df.sort_values(by='similarity', ascending=False).head(10)
# Out:
#                                           RecipeName  similarity  \
# 2                             Warm Chicken A La King    1.000000
# 16149                       Classic Chicken Ala King    0.624533
# 16772                    Garlic Mushrooms With Basil    0.536586
# 21231                           Quickie Tom Yum Soup    0.516537
# 6694                          Cajun Glazed Mushrooms    0.508901
# 22999                         Chicken With Mushrooms    0.498053
# 22271        Kittencal's Turkey or Chicken a La King    0.458257
# 19011  Champignons &agrave; L'ail (Garlic Mushrooms)    0.455482
# 7226                        Garlic Stuffed Mushrooms    0.453184
# 515                               Corn and Pea Salad    0.445987
#
#                                              Ingredients
# 2      c("chicken", "butter", "flour", "milk", "celer...
# 16149  c("butter", "flour", "salt", "pepper", "chicke...
# 16772  c("butter", "garlic cloves", "button mushrooms...
# 21231  c("garlic", "celery", "tomatoes", "button mush...
# 6694   c("button mushrooms", "unsalted butter", "marg...
# 22999  c("boneless skinless chicken thighs", "white b...
# 22271  c("butter", "fresh mushrooms", "fresh garlic",...
# 19011   c("button mushrooms", "butter", "garlic cloves")
# 7226     c("white button mushrooms", "garlic", "butter")
# 515    c("white corn", "tiny peas", "onion", "pimient...

# %% [markdown]
# By checking the name I can see that they are actually similar, the closest one in similarity to 'Warm Chicken A La King' is 'Classic Chicken Ala King' which makes a lot of sense, because it is a variation of it. Most of the recipes names include chicken, mushroom and garlic. Below I check the 3rd one 'Garlic Mushroom with Basil' since it has a similar similarity without the word 'Chicken' in its name. I assume it will be stil a bit similar cause of the words 'Mushroom' and 'Garlic'
#
# So there are indeed a lot of recipes that are closer to 'Warm Chicken A La King' than 'Chicken Breast Lombardi'. This shows why recommendation systems can be very powerful and useful!

# %%
# checking the ingridients of 2 recipes
# So i can see the whole column
pd.set_option('display.max_colwidth', None)

print(recipes['RecipeIngredientParts'][recipes['Name'] == 'Warm Chicken A La King'])
print('-------')
print(recipes['RecipeIngredientParts'][recipes['Name'] == 'Garlic Mushrooms With Basil'])


# setting the reset back to normal
pd.reset_option('display.max_colwidth')
# Out:
# 2    c("chicken", "butter", "flour", "milk", "celery", "button mushrooms", "green pepper", "canned pimiento", "salt", "black pepper", "Worcestershire sauce", "parsley")
# Name: RecipeIngredientParts, dtype: object
# -------
# 16772    c("butter", "garlic cloves", "button mushrooms", "salt", "black pepper", "cayenne pepper", "parsley", "basil")
# Name: RecipeIngredientParts, dtype: object

# %% [markdown]
# In effect the recipes have very similar ingridients. They both have butter, garlic, buttom mushrooms, salt, pepper, parsley. The only difference is the first one has chicken, sauce and milk, and the second has a different kind of pepper and basiil, but the recommendation seems on point.

# %% [markdown]
# # Function for Content Recommender
#
# Now that I have tested that the cosine similarity works with the `RecipeIngridientParts` I will do a function that will do everything I am doing on separated

# %%
def get_similar_recipes(recipe_name, recipes, similarities):
    # Get the column based on the index
    recipe_index = recipes[recipes['Name'] == recipe_name].index

    # Create a dataframe with the recipe names, similarity scores, and ingredients
    sim_df = pd.DataFrame({
        'RecipeName': recipes['Name'],
        'SimilarityScore': np.array(similarities[recipe_index, :].todense()).squeeze(),
        'Ingredients': recipes['RecipeIngredientParts']
    })

    # Sort the dataframe by similarity score in descending order
    sim_df = sim_df.sort_values(by='SimilarityScore', ascending=False)

    return sim_df.head(10)

# %%
similar_recipes = get_similar_recipes('Warm Chicken A La King', recipes, similarities)
display(similar_recipes)
# Out:
#                                           RecipeName  SimilarityScore  \
# 2                             Warm Chicken A La King         1.000000
# 16149                       Classic Chicken Ala King         0.624533
# 16772                    Garlic Mushrooms With Basil         0.536586
# 21231                           Quickie Tom Yum Soup         0.516537
# 6694                          Cajun Glazed Mushrooms         0.508901
# 22999                         Chicken With Mushrooms         0.498053
# 22271        Kittencal's Turkey or Chicken a La King         0.458257
# 19011  Champignons &agrave; L'ail (Garlic Mushrooms)         0.455482
# 7226                        Garlic Stuffed Mushrooms         0.453184
# 515                               Corn and Pea Salad         0.445987
#
#                                              Ingredients
# 2      c("chicken", "butter", "flour", "milk", "celer...
# 16149  c("butter", "flour", "salt", "pepper", "chicke...
# 16772  c("butter", "garlic cloves", "button mushrooms...
# 21231  c("garlic", "celery", "tomatoes", "button mush...
# 6694   c("button mushrooms", "unsalted butter", "marg...
# 22999  c("boneless skinless chicken thighs", "white b...
# 22271  c("butter", "fresh mushrooms", "fresh garlic",...
# 19011   c("button mushrooms", "butter", "garlic cloves")
# 7226     c("white button mushrooms", "garlic", "butter")
# 515    c("white corn", "tiny peas", "onion", "pimient...

# %% [markdown]
# Everything works as planned! So bon appetit with the recipes that you can get from this!

# %% [markdown]
# # Section5
# ## Conclusion
#
# In this notebook we explored searching, filtering, tokenizing and doing a recommendation system based on ingredients. This can be very useful, specially to new customers/visitors or people that have never left a review on the site, because the system doesn't have enough information on what he has liked before, but with the content one, they can receive recommendations based on what he searches. Also, by considering the content characteristics, the system can suggest items that share similar attributes but have not been directly interacted with by the user.

# %%
recipes2 = recipes.sort_values(by='ReviewCount', ascending=False)
recipes2 = recipes2.head(5000)
recipes2 = recipes2[['Name', 'Images','RecipeIngredientParts', 'RecipeInstructions']]

# %%
recipes2.shape
# Out:
# (5000, 4)

# %%
recipes2.head(2)
# Out:
#                    Name                                             Images  \
# 6900    Bourbon Chicken  c("https://img.sndimg.com/food/image/upload/w_...
# 243   Best Banana Bread  c("https://img.sndimg.com/food/image/upload/w_...
#
#                                   RecipeIngredientParts  \
# 6900  c("boneless chicken breasts", "olive oil", "ga...
# 243   c("butter", "granulated sugar", "eggs", "banan...
#
#                                      RecipeInstructions
# 6900  c("Editor's Note:  Named Bourbon Chicken becau...
# 243   c("Remove odd pots and pans from oven.", "Preh...

# %%
pd.set_option('display.max_colwidth', None)
display(recipes2.head(5))
pd.reset_option('display.max_colwidth')
# Out:
#                                                         Name  \
# 6900                                         Bourbon Chicken
# 243                                        Best Banana Bread
# 4123                              To Die for Crock Pot Roast
# 12169  Crock-Pot Chicken With Black Beans &amp; Cream Cheese
# 5983                              Creamy Cajun Chicken Pasta
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 6900                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 243    c("https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/wBZxNua1T8yfDwbfo9Fz_0S9A9315.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/xeKul9ZdTxKTXs3IGs16_20170323_193853.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/PuBHaYrETKPzonIe0yqD_bananabreadposter.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/klAWzgS96FaiDaqpNLig_image.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/g2B8UGjPQ3C5PDE1kFNk_20170925_154000.jpg", \n"https://img.sndimg.com/food/image/upload/v1/img/feed/2886/0AN9rGc7QE6NZq2DRh4v_20181107_181703.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/jZW5ccUWSzyiJeFry4lN_WhatsApp%20Image%202017-07-14%20at%2000.59.37.jpeg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/XiW1fNZER6u9WCrg5JAy_IMG_3591.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/6cCezmGHTgaoMzzoBsUp_IMG_20170806_143747883.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/dXzdAyzuQpeN487dGcf2_IMG_3527.JPG", \n"https://img.sndimg.com/food/image/upload/v1/img/feed/2886/gDXzkUFYRRmhm1CUwm15_Banana Bread.jpg", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/FfbZa73SQmYmLC4E1byM_10212777413820190.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/ZY7pYgUSfkYMGmi57jSw_10157193528697713.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/lZxVanQhRRqghP4poiGy_FB1F071E-FD69-47E1-8FE2-F382D4F95857.jpeg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/mjEM5MQkCMlB0JxUTOgQ_image.jpg", \n"https://img.sndimg.com/food/image/upload/v1/img/feed/2886/t8XGro3lRLmCgpM5AuOi_10219262322242781.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/w4GKsmvrTKGAc2LDZcm4_10211646507732174.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/yzxta4UPT1utb4Bu6zpz_20200419_182500.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/htYgDnOsToe7h9kndxia_nener.jpeg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/Ub2lC1KQVCfTyYukzDqy_20180319_091717.jpg", \n"https://img.sndimg.com/food/image/upload/v1/img/feed/2886/BJDJvvYHRsCAYuUH9lBP_20200223_150518~2.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/IMSXmxiR96pcKmxsWoqW_10157001496359562.jpg", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/rlFCttM3RdGES1RgpGQ1_IMG_0622.JPG", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/kvrZlWIT6OyuDrQu5jhM_Banana%20nut%20muffin.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/9tJo7KlNQ0W8rnceL5LM_The_best_way_to_use_up_overripe_bananas_-_banana_loaf_.bananabread_bananaloaf_bananas_cake_bread_homebaker_homebaked_hom.jpg", \n"https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/utXJw0HCRNa71PsN12nx_E210CF94-C70F-43CA-B475-8F8A20BDBA00.jpeg", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/hU82gqTASDGDi5NpwHIZ_IMG_0470.JPG", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/w5R2HvGXRQOZ73BHmRh8_IMG_20170806_143747883.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/Nzw2PcrWQtmRl3Zog7y6_106293530_1504644113048218_1759332707114193313_n.jpg", \n"https://img.sndimg.com/food/image/upload/v1/img/feed/2886/aRFlgsTeRVeRkBmZCnDY_15895972946162567917419397203426.jpg", "https://img.sndimg.com/food/image/upload/v1/img/feed/2886/6kAiQMjGRUyBrLDF8BXh_C363FACD-1A4E-4998-8D4B-49A35B484066.jpeg", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/aQXgUKNT1WusRoL5rXQd_2528725314010607.jpg", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/28/86/SWChMwJ8TlqlShguhz20_2528725337343938.jpg", \n"https://img.sndimg.com/food/image/upload/w_555,h_416, ...
# 4123                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 12169                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# 5983                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
#
#                                                                                                                                                                                                                           RecipeIngredientParts  \
# 6900                                                                   c("boneless chicken breasts", "olive oil", "garlic clove", "ginger", "crushed red pepper flakes", "light brown sugar", "ketchup", "cider vinegar", "water", "soy sauce")
# 243                                                                                                                                   c("butter", "granulated sugar", "eggs", "bananas", "all-purpose flour", "baking soda", "salt", "vanilla")
# 4123                                                                                                                                                                                                                   c("beef roast", "water")
# 12169                                                                                                                                                             c("boneless chicken breasts", "black beans", "corn", "salsa", "cream cheese")
# 5983   c("boneless skinless chicken breast halves", "linguine", "Cajun Seasoning Mix", "butter", "green onion", "heavy whipping cream", "sun-dried tomatoes", "salt", "dried basil", "ground black pepper", "garlic powder", "parmesan cheese")
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                       RecipeInstructions
# 6900   c("Editor's Note:  Named Bourbon Chicken because it was supposedly created by a Chinese cook who worked in a restaurant on Bourbon Street.", "Heat oil in a large skillet.", "Add chicken pieces and cook until lightly browned.", "Remove chicken.", "Add remaining ingredients, heating over medium Heat until well mixed and dissolved.", "Add chicken and bring to a hard boil.", "Reduce heat and simmer for 20 minutes.", "Serve over hot rice and ENJOY.")
# 243                                                                c("Remove odd pots and pans from oven.", "Preheat oven to 350º / 180º.", "Cream together butter and sugar.", "Add eggs and crushed bananas.", "Combine well.", "Sift together flour, soda and salt. Add to creamed mixture. Add vanilla.", "Mix just until combined. Do not overmix.", "Pour into greased and floured loaf pan.", "Bake at 350º / 180º for 55 minutes.", "Keeps well, refrigerated.")
# 4123                                                                                      c("Place beef roast in crock pot.", "Mix the dried mixes together in a bowl and sprinkle over the roast.", "Pour the water around the roast.", "Cook on low for 7-9 hours.", "Optional tweaks:", "1. Use onion soup mix instead of ranch.", "2. Add one cup of red wine along with the water.", "3. Add potatoes, carrots, mushrooms, celery and onion 2-3 hours before end.")
# 12169                                                                                                          c("Take 4-5 frozen, yes, frozen, boneless chicken breasts put into crock pot.", "Add 1 can of black beans, drained, 1 jar of salsa, 1 can of corn drained.", "Keep in crock pot on high for about 4-5 hours or until chicken is cooked.", "Add 1 package of cream cheese (just throw it on top!) and let sit for about 1/2 hour.", "All done and enjoy!")
# 5983                                                                                           c("Place chicken and Cajun seasoning in a bowl and toss to coat.", "In a large skillet over medium heat, sauté chicken in butter or margarine until chicken is tender, about 5 to 7 minutes.", "Reduce heat add green onion, heavy cream, tomatoes, basil, salt, garlic powder, black pepper and heat through.", "Pour over hot linguine and toss with Parmesan cheese.")

# %%
import re

# Extract the first image link using regular expressions
recipes2['Images'] = recipes2['Images'].str.extract(r'(http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+)')

# Display the modified recipe2 DataFrame
display(recipes2.head(3))
# Out:
#                             Name  \
# 6900             Bourbon Chicken
# 243            Best Banana Bread
# 4123  To Die for Crock Pot Roast
#
#                                                  Images  \
# 6900  https://img.sndimg.com/food/image/upload/w_555...
# 243   https://img.sndimg.com/food/image/upload/w_555...
# 4123  https://img.sndimg.com/food/image/upload/w_555...
#
#                                   RecipeIngredientParts  \
# 6900  c("boneless chicken breasts", "olive oil", "ga...
# 243   c("butter", "granulated sugar", "eggs", "banan...
# 4123                           c("beef roast", "water")
#
#                                      RecipeInstructions
# 6900  c("Editor's Note:  Named Bourbon Chicken becau...
# 243   c("Remove odd pots and pans from oven.", "Preh...
# 4123  c("Place beef roast in crock pot.", "Mix the d...

# %%
recipes2 = recipes2.reset_index(drop=True)
recipes2.to_feather('streamlit_files/5k_recipes.feather')

# %%
TFIDF_matrix_5k = vectorizer.fit_transform(recipes2['RecipeIngredientParts'])

# %%
TFIDF_matrix_5k.shape
# Out:
# (5000, 293)

# %%
joblib.dump(TFIDF_matrix_5k, 'pkl/tfidf_content_matrix.pkl')
# Out:
# ['pkl/tfidf_content_matrix.pkl']

# %%
recipes2.to_csv('streamlit_files/good_rated_recipes.csv', index=False)
